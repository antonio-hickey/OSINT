# %% [markdown]
# # Example of Satellite Images collected from my [Bot](https://git.io/JJLpk)
# ### Inidan Tibetan Border Police Base
#
# #### Point 1 (right)
# - Lat: (33 44 25 N)
# - Lon: (078 44 45 E)
#
# #### Point 2 (left)
# - Lat: (33 44 26 N)
# - Lon: (078 45 02 E)

# %% [markdown]
# <img src='India2020-07-03.png' width=600 height=600>

# %% [markdown]
# ### (China) Peoples Liberation Army Indian Front
#
# #### Point 1 (right)
# - Lat: (33 44 25 N)
# - Lon: (078 52 35 E)
#
# #### Point 2 (left)
# - Lat: (33 44 25 N)
# - Lon: (078 52 36 E)

# %% [markdown]
# <img src='China-2020-07-06.png' width=600 height=600>
